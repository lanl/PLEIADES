# %% [markdown]
# # ORNL VENUS Neutron Transmission Analysis: Tantalum-181
#
# ## Instrument: VENUS (Versatile Neutron Imaging Station)
# ## Facility: Oak Ridge National Laboratory

# %%
from dotenv import load_dotenv
load_dotenv('../../../.envrc')
# Out:
# True

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# ## Environment Configuration

# %%
# Verify resolution function environment variable
resolution_file_path = Path(os.environ.get('VENUS_RES_FUNC', ''))
if not resolution_file_path.exists():
    raise FileNotFoundError(f"Resolution file not found at VENUS_RES_FUNC: {resolution_file_path}")

# VENUS data paths
ipts_path = "/SNS/VENUS/IPTS-35945"
nexus_path = f"{ipts_path}/nexus"
autoreduce_base = f"{ipts_path}/shared/autoreduce/mcp/images"

# Analysis directories
working_dir = "./ta_analysis"
os.makedirs(working_dir, exist_ok=True)
spectra_dir = f"{working_dir}/spectra"
os.makedirs(spectra_dir, exist_ok=True)
twenty_dir = f"{working_dir}/twenty"
os.makedirs(twenty_dir, exist_ok=True)
sammy_working = Path(working_dir) / "sammy_working"
sammy_output = Path(working_dir) / "sammy_output"
sammy_working.mkdir(exist_ok=True)
sammy_output.mkdir(exist_ok=True)

# %% [markdown]
# ## Data Processing

# %%
from pleiades.processing.normalization import normalization
from pleiades.processing import Roi, Facility

open_beam_folder = f"{autoreduce_base}/Run_8109"
sample_folders = [
    f"{autoreduce_base}/Run_8111"
]

# %%
transmissions = normalization(
    list_sample_folders=sample_folders,
    list_obs_folders=[open_beam_folder],
    nexus_path=nexus_path,
    facility=Facility.ornl,
    combine_mode=False,
    pc_uncertainty=0.005,
    output_folder=os.path.join(working_dir, "spectra"),
)
# Out:
# 2025-09-25 15:30:49 | INFO     | pleiades.processing.normalization:normalization:91 - Using ORNL-specific normalization
# olefile module not found
# /SNS/users/8cz/github.com/PLEIADES/.pixi/envs/default/lib/python3.11/site-packages/dxchange/__init__.py:63: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 2025-09-25 15:30:53 | INFO     | pleiades.processing.normalization_ornl:normalization_ornl:199 - Loading 1 sample folders
# 2025-09-25 15:30:53 | INFO     | pleiades.utils.load:load:21 - loading 4367 files with extension .tif
# 2025-09-25 15:31:41 | DEBUG    | pleiades.processing.helper_ornl:load_spectra_file:42 - Found spectra file: Run_8111_20250425_April24_2025_MCP_TPX_Foil_Ta_Far_1_6C_Resonance_0001_2674034_Spectra.txt
# 2025-09-25 15:31:41 | INFO     | pleiades.processing.helper_ornl:load_multiple_runs:177 - Loaded 1 runs
# 2025-09-25 15:31:41 | INFO     | pleiades.processing.normalization_ornl:normalization_ornl:202 - Loading 1 OB folders
# 2025-09-25 15:31:41 | INFO     | pleiades.utils.load:load:21 - loading 4367 files with extension .tif
# 2025-09-25 15:32:31 | DEBUG    | pleiades.processing.helper_ornl:load_spectra_file:42 - Found spectra file: Run_8109_20250424_April24_2025_OB_MCP_TPX1_Foil_1_6C_Resonance_0001_2672032_Spectra.txt
# 2025-09-25 15:32:31 | INFO     | pleiades.processing.helper_ornl:load_multiple_runs:177 - Loaded 1 runs
# 2025-09-25 15:32:31 | INFO     | pleiades.processing.normalization_ornl:normalization_ornl:210 - Using individual mode
# 2025-09-25 15:32:31 | INFO     | pleiades.processing.normalization_ornl:process_individual_mode:123 - Combined 1 OB runs
# 2025-09-25 15:32:31 | DEBUG    | pleiades.processing.normalization_ornl:process_individual_mode:128 - Processing sample run 1/1
# 2025-09-25 15:32:31 | DEBUG    | pleiades.processing.helper_ornl:detect_persistent_dead_pixels:193 - Found 95/262144 dead pixels (0.0%)
# 2025-09-25 15:32:31 | DEBUG    | pleiades.processing.helper_ornl:detect_persistent_dead_pixels:193 - Found 93/262144 dead pixels (0.0%)
# 2025-09-25 15:32:32 | INFO     | pleiades.processing.normalization_ornl:normalization_ornl:249 - Saved transmission to ./ta_analysis/spectra/Run_8111_transmission.txt

# %%
# Transmission spectrum visualization
fig, ax = plt.subplots(figsize=(10, 6))
for transmission in transmissions:
    label = transmission.metadata.get("sample_folder", "Unknown").split("/")[-1]
    ax.plot(transmission.energy, transmission.transmission, label=label)
ax.set_xlabel("Energy (eV)")
ax.set_ylabel("Transmission")
ax.set_xscale("log")
ax.set_yscale("log")
ax.grid(True, which="both", ls="--", lw=0.5)
ax.legend()
ax.set_title("Ta-181 Transmission Spectrum")
plt.show()

# %% [markdown]
# ## SAMMY Data Format Conversion

# %%
from pleiades.sammy.io.data_manager import convert_csv_to_sammy_twenty, validate_sammy_twenty_format

input_dir = Path(spectra_dir)
output_dir = Path(twenty_dir)

csv_files = list(input_dir.glob("*_transmission.txt"))
print(f"Converting {len(csv_files)} transmission files")

for csv_file in csv_files:
    twenty_file = output_dir / csv_file.name.replace(".txt", ".twenty")
    convert_csv_to_sammy_twenty(csv_file, twenty_file)
    if validate_sammy_twenty_format(twenty_file):
        print(f"Converted: {twenty_file.name}")
# Out:
# 2025-09-25 15:32:33 | INFO     | pleiades.sammy.io.data_manager:convert_csv_to_sammy_twenty:54 - Converting ta_analysis/spectra/Run_8111_transmission.txt to SAMMY twenty format: ta_analysis/twenty/Run_8111_transmission.twenty
# 2025-09-25 15:32:33 | INFO     | pleiades.sammy.io.data_manager:convert_csv_to_sammy_twenty:124 - Converted 4367 data points to twenty format
# 2025-09-25 15:32:33 | INFO     | pleiades.sammy.io.data_manager:validate_sammy_twenty_format:164 - File ta_analysis/twenty/Run_8111_transmission.twenty is valid SAMMY twenty format
# Converting 1 transmission files
# Converted: Run_8111_transmission.twenty

# %% [markdown]
# ## SAMMY Configuration
#
# Ta-180m lacks resonance data in ENDF-B/VIII.0. Analysis proceeds with Ta-181 only (99.988% natural abundance).

# %%
from pleiades.sammy.io.json_manager import JsonManager

json_manager = JsonManager()
json_path = json_manager.create_json_config(
    isotopes=["Ta-181"],
    abundances=[1.0],
    working_dir=working_dir,
    custom_global_settings={
        "forceRMoore": "yes",
        "purgeSpinGroups": "yes",
        "fudge": "0.7"
    }
)

print(f"JSON configuration: {json_path}")
endf_files = [f for f in os.listdir(working_dir) if f.endswith('.par')]
print(f"ENDF files: {len(endf_files)}")
# Out:
# 2025-09-25 15:32:33 | INFO     | pleiades.sammy.io.json_manager:__init__:165 - JsonManager initialized with Pydantic v2 models
# 2025-09-25 15:32:33 | INFO     | pleiades.sammy.io.json_manager:create_json_config:214 - Creating SAMMY workspace for 1 isotopes: ['Ta-181']
# 2025-09-25 15:32:33 | INFO     | pleiades.sammy.io.json_manager:create_json_config:215 - Working directory: ta_analysis
# 2025-09-25 15:32:33 | INFO     | pleiades.sammy.io.json_manager:create_json_config:218 - Step 1: Staging ENDF files...
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.isotopes.manager:get_isotope_info:167 - Getting isotope parameters for Ta-181
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.isotopes.manager:get_file_path:75 - Searching for mass.mas20 in cached files for FileCategory.ISOTOPES: {PosixPath('/SNS/users/8cz/github.com/PLEIADES/src/pleiades/nuclear/isotopes/files/mass.mas20'), PosixPath('/SNS/users/8cz/github.com/PLEIADES/src/pleiades/nuclear/isotopes/files/isotopes.info'), PosixPath('/SNS/users/8cz/github.com/PLEIADES/src/pleiades/nuclear/isotopes/files/neutrons.list')}
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.isotopes.manager:get_file_path:77 - Checking file: mass.mas20
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.isotopes.manager:get_file_path:79 - Found file: /SNS/users/8cz/github.com/PLEIADES/src/pleiades/nuclear/isotopes/files/mass.mas20
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.isotopes.manager:get_file_path:75 - Searching for isotopes.info in cached files for FileCategory.ISOTOPES: {PosixPath('/SNS/users/8cz/github.com/PLEIADES/src/pleiades/nuclear/isotopes/files/mass.mas20'), PosixPath('/SNS/users/8cz/github.com/PLEIADES/src/pleiades/nuclear/isotopes/files/isotopes.info'), PosixPath('/SNS/users/8cz/github.com/PLEIADES/src/pleiades/nuclear/isotopes/files/neutrons.list')}
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.isotopes.manager:get_file_path:77 - Checking file: mass.mas20
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.isotopes.manager:get_file_path:77 - Checking file: isotopes.info
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.isotopes.manager:get_file_path:79 - Found file: /SNS/users/8cz/github.com/PLEIADES/src/pleiades/nuclear/isotopes/files/isotopes.info
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.isotopes.manager:get_file_path:75 - Searching for neutrons.list in cached files for FileCategory.ISOTOPES: {PosixPath('/SNS/users/8cz/github.com/PLEIADES/src/pleiades/nuclear/isotopes/files/mass.mas20'), PosixPath('/SNS/users/8cz/github.com/PLEIADES/src/pleiades/nuclear/isotopes/files/isotopes.info'), PosixPath('/SNS/users/8cz/github.com/PLEIADES/src/pleiades/nuclear/isotopes/files/neutrons.list')}
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.isotopes.manager:get_file_path:77 - Checking file: mass.mas20
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.isotopes.manager:get_file_path:77 - Checking file: isotopes.info
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.isotopes.manager:get_file_path:77 - Checking file: neutrons.list
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.isotopes.manager:get_file_path:79 - Found file: /SNS/users/8cz/github.com/PLEIADES/src/pleiades/nuclear/isotopes/files/neutrons.list
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.manager:download_endf_resonance_file:361 - Using cached ENDF data from /SNS/users/8cz/.pleiades/nuclear_data/DataRetrievalMethod.API/EndfLibrary.ENDF_B_VIII_0/n_073-Ta-181_7328_resonance.dat
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.manager:download_endf_resonance_file:390 - API method returned resonance data directly, no extraction needed
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.manager:download_endf_resonance_file:392 - Resonance parameters written to ta_analysis/073-Ta-181.B-VIII.0.par
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.manager:download_endf_resonance_file:396 - Note: Only resonance data was downloaded (API method)
# 2025-09-25 15:32:33 | DEBUG    | pleiades.sammy.io.json_manager:create_json_config:235 - Staged Ta-181: 073-Ta-181.B-VIII.0.par
# 2025-09-25 15:32:33 | INFO     | pleiades.sammy.io.json_manager:create_json_config:244 - Step 2: Creating JSON configuration with actual ENDF filenames...
# 2025-09-25 15:32:33 | INFO     | pleiades.nuclear.isotopes.manager:get_isotope_info:167 - Getting isotope parameters for Ta-181
# 2025-09-25 15:32:33 | DEBUG    | pleiades.sammy.io.json_manager:add_isotope_entry:95 - Added isotope entry: 073-Ta-181.B-VIII.0.par
# 2025-09-25 15:32:33 | DEBUG    | pleiades.sammy.io.json_manager:create_json_config:272 - Added Ta-181 (MAT=7328) as 073-Ta-181.B-VIII.0.par
# 2025-09-25 15:32:33 | INFO     | pleiades.sammy.io.json_manager:create_json_config:285 - JSON configuration written to: ta_analysis/config.json
# 2025-09-25 15:32:33 | INFO     | pleiades.sammy.io.json_manager:create_json_config:286 - Configuration contains 1 isotope entries
# 2025-09-25 15:32:33 | INFO     | pleiades.sammy.io.json_manager:create_json_config:287 - SAMMY workspace complete: 1 ENDF files + 1 JSON file
# JSON configuration: ta_analysis/config.json
# ENDF files: 1

# %%
from pleiades.sammy.io.inp_manager import InpManager

ta_material_props = {
    'element': 'Ta',
    'mass_number': 181,
    'density_g_cm3': 16.65,
    'thickness_mm': 0.127,
    'atomic_mass_amu': 180.94788,
    'abundance': 1.0,
    'min_energy': 1.0,
    'max_energy_eV': 200.0,
    'temperature_K': 293.6
}

inp_file = Path(working_dir) / "ta_fitting.inp"
InpManager.create_multi_isotope_inp(
    inp_file,
    title="Ta-181 neutron transmission analysis - VENUS IPTS-35945",
    material_properties=ta_material_props,
    resolution_file_path=resolution_file_path
)

print(f"INP file: {inp_file}")
# Out:
# 2025-09-25 15:32:34 | INFO     | pleiades.utils.logger:__init__:145 - logging initialized...
# 2025-09-25 15:32:34 | INFO     | pleiades.sammy.io.inp_manager:create_multi_isotope_inp:480 - Successfully wrote multi-isotope SAMMY input file to ta_analysis/ta_fitting.inp
# INP file: ta_analysis/ta_fitting.inp

# %%
from pleiades.sammy.backends.local import LocalSammyRunner
from pleiades.sammy.config import LocalSammyConfig
from pleiades.sammy.interface import SammyFilesMultiMode

data_file = Path(twenty_dir) / "Run_8111_transmission.twenty"

files = SammyFilesMultiMode(
    input_file=inp_file,
    json_config_file=Path(json_path),
    data_file=data_file,
    endf_directory=Path(working_dir)
)

config = LocalSammyConfig(
    sammy_executable=Path("/SNS/software/sammy/bin/sammy"),
    working_dir=sammy_working,
    output_dir=sammy_output
)

runner = LocalSammyRunner(config)

# %% [markdown]
# ## SAMMY Execution

# %%
print("Executing SAMMY fitting")
runner.prepare_environment(files)
result = runner.execute_sammy(files)

print(f"Execution status: {result.success}")
print(f"Runtime: {result.runtime_seconds:.2f} s")

if result.error_message:
    print(f"Error: {result.error_message[:200]}")

runner.collect_outputs(result=result)
runner.cleanup()
# Out:
# 2025-09-25 15:32:34 | DEBUG    | pleiades.sammy.backends.local:prepare_environment:45 - Validating input files
# 2025-09-25 15:32:34 | DEBUG    | pleiades.sammy.backends.local:prepare_environment:50 - Performing JSON-ENDF mapping validation
# 2025-09-25 15:32:34 | DEBUG    | pleiades.sammy.backends.local:_validate_json_endf_mapping:100 - JSON-ENDF validation passed: 1 ENDF files verified
# 2025-09-25 15:32:34 | DEBUG    | pleiades.sammy.backends.local:prepare_environment:54 - Moving files to working directory
# 2025-09-25 15:32:34 | DEBUG    | pleiades.sammy.interface:move_to_working_dir:214 - Moving JSON mode files to working directory: ta_analysis/sammy_working
# 2025-09-25 15:32:34 | DEBUG    | pleiades.sammy.interface:move_to_working_dir:253 - Symlinked ENDF file: 073-Ta-181.B-VIII.0.par
# 2025-09-25 15:32:34 | DEBUG    | pleiades.sammy.backends.local:prepare_environment:58 - Environment preparation complete
# 2025-09-25 15:32:34 | INFO     | pleiades.sammy.backends.local:execute_sammy:110 - Starting SAMMY execution 87559509-067f-4249-95d1-3fc24091043a
# 2025-09-25 15:32:34 | DEBUG    | pleiades.sammy.backends.local:execute_sammy:111 - Working directory: ta_analysis/sammy_working
# 2025-09-25 15:32:34 | DEBUG    | pleiades.sammy.backends.local:execute_sammy:123 - Using JSON mode command format
# Executing SAMMY fitting
# 2025-09-25 15:32:37 | INFO     | pleiades.sammy.backends.local:execute_sammy:156 - SAMMY execution completed successfully for 87559509-067f-4249-95d1-3fc24091043a
# 2025-09-25 15:32:37 | INFO     | pleiades.sammy.interface:collect_outputs:432 - Collecting outputs for execution 87559509-067f-4249-95d1-3fc24091043a
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:443 - Found known output file: SAMNDF.INP
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:443 - Found known output file: SAMNDF.PAR
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:443 - Found known output file: SAMMY.IO
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:443 - Found known output file: SAMMY.LST
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:443 - Found known output file: SAMMY.ODF
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:443 - Found known output file: SAMMY.LPT
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:449 - Found additional output file: SAMQUA.RED
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:449 - Found additional output file: SAMMY.PLT
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:449 - Found additional output file: SAMQUA.PAR
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:449 - Found additional output file: SAMMY.PAR
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:449 - Found additional output file: SAM46.DAT
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:449 - Found additional output file: SAM41.DAT
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:449 - Found additional output file: SAMMY.RED
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:449 - Found additional output file: SAMMY.COV
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:466 - Moved ta_analysis/sammy_working/SAM41.DAT to ta_analysis/sammy_output/SAM41.DAT
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:466 - Moved ta_analysis/sammy_working/SAMMY.ODF to ta_analysis/sammy_output/SAMMY.ODF
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:466 - Moved ta_analysis/sammy_working/SAMNDF.INP to ta_analysis/sammy_output/SAMNDF.INP
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:466 - Moved ta_analysis/sammy_working/SAMMY.PLT to ta_analysis/sammy_output/SAMMY.PLT
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:466 - Moved ta_analysis/sammy_working/SAMMY.RED to ta_analysis/sammy_output/SAMMY.RED
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:466 - Moved ta_analysis/sammy_working/SAMMY.COV to ta_analysis/sammy_output/SAMMY.COV
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:466 - Moved ta_analysis/sammy_working/SAMMY.IO to ta_analysis/sammy_output/SAMMY.IO
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:466 - Moved ta_analysis/sammy_working/SAMQUA.RED to ta_analysis/sammy_output/SAMQUA.RED
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:466 - Moved ta_analysis/sammy_working/SAMQUA.PAR to ta_analysis/sammy_output/SAMQUA.PAR
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:466 - Moved ta_analysis/sammy_working/SAMNDF.PAR to ta_analysis/sammy_output/SAMNDF.PAR
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:466 - Moved ta_analysis/sammy_working/SAMMY.PAR to ta_analysis/sammy_output/SAMMY.PAR
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:466 - Moved ta_analysis/sammy_working/SAMMY.LPT to ta_analysis/sammy_output/SAMMY.LPT
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:466 - Moved ta_analysis/sammy_working/SAM46.DAT to ta_analysis/sammy_output/SAM46.DAT
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.interface:collect_outputs:466 - Moved ta_analysis/sammy_working/SAMMY.LST to ta_analysis/sammy_output/SAMMY.LST
# 2025-09-25 15:32:37 | INFO     | pleiades.sammy.interface:collect_outputs:471 - Successfully collected 14 output files in 0.05 seconds
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.backends.local:cleanup:174 - Performing cleanup for local backend
# Execution status: True
# Runtime: 2.97 s

# %% [markdown]
# ## Results Analysis

# %%
from pleiades.sammy.results.manager import ResultsManager

lpt_file_path = sammy_output / "SAMMY.LPT"
lst_file_path = sammy_output / "SAMMY.LST"

results_manager = ResultsManager(lpt_file_path=lpt_file_path, lst_file_path=lst_file_path)
data = results_manager.get_data()

print(f"Energy range: {data.energy.min():.3e} - {data.energy.max():.3e} eV")
print(f"Data points: {len(data.energy)}")
# Out:
# 2025-09-25 15:32:37 | INFO     | pleiades.sammy.io.lpt_manager:process_lpt_file:479 - Successfully read the file: ta_analysis/sammy_output/SAMMY.LPT
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.io.lpt_manager:process_lpt_file:490 - Split LPT content into 3 blocks.
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.io.lpt_manager:extract_isotope_info:116 - Extracting isotope information...
# 2025-09-25 15:32:37 | INFO     | pleiades.sammy.io.lpt_manager:extract_results_from_string:415 - Isotope results not found.
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.io.lpt_manager:extract_radius_info:189 - Extracting radius information...
# 2025-09-25 15:32:37 | INFO     | pleiades.sammy.io.lpt_manager:extract_results_from_string:418 - Radius results not found.
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.io.lpt_manager:extract_broadening_info:261 - Extracting broadening information...
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.io.lpt_manager:extract_normalization_info:328 - Extracting normalization information...
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.io.lpt_manager:extract_chi_squared_info:377 - Extracting chi-squared information...
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.io.lpt_manager:extract_isotope_info:116 - Extracting isotope information...
# 2025-09-25 15:32:37 | INFO     | pleiades.sammy.io.lpt_manager:extract_results_from_string:415 - Isotope results not found.
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.io.lpt_manager:extract_radius_info:189 - Extracting radius information...
# 2025-09-25 15:32:37 | INFO     | pleiades.sammy.io.lpt_manager:extract_results_from_string:418 - Radius results not found.
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.io.lpt_manager:extract_broadening_info:261 - Extracting broadening information...
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.io.lpt_manager:extract_normalization_info:328 - Extracting normalization information...
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.io.lpt_manager:extract_chi_squared_info:377 - Extracting chi-squared information...
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.io.lpt_manager:extract_isotope_info:116 - Extracting isotope information...
# 2025-09-25 15:32:37 | INFO     | pleiades.sammy.io.lpt_manager:extract_results_from_string:415 - Isotope results not found.
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.io.lpt_manager:extract_radius_info:189 - Extracting radius information...
# 2025-09-25 15:32:37 | INFO     | pleiades.sammy.io.lpt_manager:extract_results_from_string:418 - Radius results not found.
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.io.lpt_manager:extract_broadening_info:261 - Extracting broadening information...
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.io.lpt_manager:extract_normalization_info:328 - Extracting normalization information...
# 2025-09-25 15:32:37 | DEBUG    | pleiades.sammy.io.lpt_manager:extract_chi_squared_info:377 - Extracting chi-squared information...
# Energy range: 6.673e+00 - 1.999e+02 eV
# Data points: 3575

# %%
# Experimental vs theoretical transmission comparison
plt.figure(figsize=(10, 6))
plt.plot(data.energy, data.experimental_transmission, '.', markersize=1, label='Experimental', alpha=0.5)
plt.plot(data.energy, data.theoretical_transmission, '-', linewidth=1, label='Theoretical', color='red')
plt.xlabel('Energy (eV)')
plt.ylabel('Transmission')
plt.legend()
plt.grid(True, alpha=0.3)
plt.xscale('log')
plt.title('Ta-181: Experimental vs Theoretical Transmission')
plt.show()

# %% [markdown]
# ## Fitting Quality Metrics

# %%
if results_manager.run_results.fit_results:
    print(f"Fit iterations: {len(results_manager.run_results.fit_results)}")
    
    for i, fit_result in enumerate(results_manager.run_results.fit_results):
        print(f"\nIteration {i+1}:")
        
        chi_sq = fit_result.get_chi_squared_results()
        if chi_sq.chi_squared is not None:
            print(f"  Chi-squared: {chi_sq.chi_squared:.4f}")
            print(f"  Data points: {chi_sq.dof}")
            print(f"  Reduced chi-squared: {chi_sq.reduced_chi_squared:.6f}")
        
        physics = fit_result.get_physics_data()
        if hasattr(physics, 'broadening_parameters'):
            broadening = physics.broadening_parameters
            if hasattr(broadening, 'thick') and broadening.thick is not None:
                print(f"  Number density: {broadening.thick:.6e} atoms/barn-cm")
                print(f"  Temperature: {broadening.temp:.2f} K")

    # Final results
    if len(results_manager.run_results.fit_results) > 0:
        final_fit = results_manager.run_results.fit_results[-1]
        final_chi = final_fit.get_chi_squared_results()
        final_phys = final_fit.get_physics_data()
        
        print("\nFinal fit results:")
        if final_chi.reduced_chi_squared:
            print(f"  Reduced chi-squared: {final_chi.reduced_chi_squared:.6f}")
        if hasattr(final_phys, 'broadening_parameters'):
            if hasattr(final_phys.broadening_parameters, 'thick'):
                print(f"  Number density: {final_phys.broadening_parameters.thick:.6e} atoms/barn-cm")
# Out:
# Fit iterations: 3
#
# Iteration 1:
#   Chi-squared: 436342.0000
#   Data points: 3575
#   Reduced chi-squared: 122.054000
#   Number density: 7.040000e-04 atoms/barn-cm
#   Temperature: 293.60 K
#
# Iteration 2:
#   Chi-squared: 77205.3000
#   Data points: 3575
#   Reduced chi-squared: 21.595900
#   Number density: 8.172900e-04 atoms/barn-cm
#   Temperature: 293.60 K
#
# Iteration 3:
#   Chi-squared: 25096.0000
#   Data points: 3575
#   Reduced chi-squared: 7.019870
#   Number density: 7.876200e-04 atoms/barn-cm
#   Temperature: 293.60 K
#
# Final fit results:
#   Reduced chi-squared: 7.019870
#   Number density: 7.876200e-04 atoms/barn-cm
